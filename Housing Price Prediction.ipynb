# %% [markdown]
# ## Housing Price Prediction

# %% [markdown]
# #### Import dependencies

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree,ensemble
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Import the data

# %%
data = pd.read_csv(r'C:\Users\1085679\Documents\ML_Practice\train.csv',encoding='ISO-8859-1')

# %% [markdown]
# #### Analyze the data

# %%
print(data.head())
print(data.describe())
print(data.info())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# #### Null values in dataset

# %%
print(data.isnull().sum())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %% [markdown]
# #### Impute missing data

# %%
for col in data.columns:
    if data[col].isnull().sum()>0.3*len(data[col]):
        data.drop(col,axis=1,inplace=True)
    elif data[col].isnull().sum()>1:
        data.fillna(method='ffill',inplace=True)
        data.fillna(method='bfill',inplace=True)

# %% [markdown]
# #### Analyze Categorical Columns

# %%
data_cat = data.select_dtypes(include='object')
data_cat.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %% [markdown]
# #### Drop Neighbourhood column due to more number of unique values

# %%
data_cat.drop('Neighborhood',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# #### Encoding categorical variables

# %%
for i in data_cat.columns:
    temp = pd.get_dummies(data_cat[i],prefix=str(i)+'_')
    data_cat = pd.concat([data_cat,temp],axis=1)
    data_cat.drop(i,axis=1,inplace=True)

# %%
data_num = data.select_dtypes(include=['int64','float64'])
# data_num.describe()
df=pd.concat([data_cat,data_num],axis=1)

# %% [markdown]
# #### Splitting data into train and test set

# %%
train_x,test_x,train_y,test_y = train_test_split(df.iloc[:,:-1],df.iloc[:,-1],random_state=0)

# %% [markdown]
# #### Linear Regression

# %%
linear_reg = LinearRegression()
linear_reg.fit(train_x,train_y)
linear_reg.score(test_x,test_y)
# Out:
# -58738801.44414648

# %% [markdown]
# #### Decision Tree

# %%
dtreg = tree.DecisionTreeRegressor()
dtreg.fit(train_x,train_y)
dtreg.score(test_x,test_y)
# Out:
# 0.686405246356532

# %% [markdown]
# #### Random Forest

# %%
rfclass = ensemble.RandomForestRegressor()
rfclass.fit(train_x,train_y)
rfclass.score(test_x,test_y)
# Out:
# C:\Users\1085679\AppData\Roaming\Python\Python37\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8278960213204741

# %% [markdown]
# #### XGBoost

# %%
import xgboost as xgb
model = xgb.XGBRegressor()
model.fit(train_x,train_y)
model.score(test_x,test_y)
# Out:
# 0.886605843132648

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np
pred=model.predict(test_x)
mean_absolute_error(pred,test_y)
# Out:
# 16204.24691780822

# %% [markdown]
# #### Tuning Depth of tree

# %%
fitted_tree_depth = dtreg.tree_.max_depth
print(fitted_tree_depth)
temp=[0]
tem_train=[0]
for i in range(1,fitted_tree_depth):
    dtreg.fit(train_x,train_y)
    temp.append(dtreg.score(test_x,test_y))
    tem_train.append(dtreg.score(train_x,train_y))
#     print(dtreg.score(test_x,test_y))
    pred = dtreg.predict(test_x)
    print(mean_absolute_error(pred,test_y))
#     count=0
#     if i>0:
#         if temp[i]>temp[i-1] or count=0: 
#             count+=1
#             continue
#         else:
#             break
# Out:
# 26
# 27574.46301369863
# 27207.084931506848
# 26651.843835616437
# 27892.8602739726
# 26555.364383561642
# 27047.476712328767
# 27130.038356164383
# 25134.19178082192
# 26788.479452054795
# 28674.60821917808
# 27539.29589041096
# 27113.15068493151
# 27346.361643835615
# 26199.780821917808
# 27662.01917808219
# 27007.8301369863
# 27702.01095890411
# 27063.47397260274
# 26154.172602739727
# 27201.824657534245
# 28173.07123287671
# 27295.512328767123
# 27758.70410958904
# 26153.186301369864
# 26722.616438356163

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(len(temp)),temp)
plt.plot(range(len(temp)),tem_train)
plt.legend(['test','train'])

# %%
max_dep = temp.index(max(temp))
dtreg = tree.DecisionTreeRegressor(max_depth=max_dep)
dtreg.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=7, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred = dtreg.predict(test_x)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import numpy as np
np.sqrt(mean_absolute_error(pred,test_y))
np.sqrt(mean_squared_error(pred,test_y))
# Out:
# 3.921398655258291

# %%
from sklearn.tree import export_graphviz
export_graphviz(dtreg, out_file="dot_data.dot",feature_names=data.iloc[:,:-1].columns)

# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display                               
from ipywidgets import interactive

graph = Source(tree.export_graphviz(dtreg
      , out_file=None
      , feature_names=data.iloc[:,:-1].columns
      , filled = True))
   
display(SVG(graph.pipe(format='svg')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     145     try:
# --> 146         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     147     except OSError as e:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     755                                 errread, errwrite,
# --> 756                                 restore_signals, start_new_session)
#     757         except:
#
# ...
